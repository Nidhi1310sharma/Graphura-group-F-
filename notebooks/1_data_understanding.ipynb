# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/cleaned_data.csv")

# %%
df.head()
# Out:
#                                                title                  company  \
# 0  Finance Research Analyst - Internship (WFH & P...             Edify Equity
# 1                         Digital Marketing (Female)        Wear It Like This
# 2                Social Media Marketing - Internship     Madhuram Hospitality
# 3                             Pre Sales - Internship        Dronacharya Group
# 4  Marketing Support (Female Candidates) - Intern...  Neeti Brand Accelerator
#
#                   location                   stipend  duration   start_date  \
# 0                    Delhi    ₹ 1,000 - 1,100 /month   1 Month  Immediately
# 1  Secunderabad, Hyderabad  ₹ 10,000 - 15,000 /month  3 Months  Immediately
# 2                Bangalore   ₹ 5,000 - 10,000 /month  3 Months  Immediately
# 3                 Bhilwara   ₹ 9,500 - 16,000 /month  3 Months  Immediately
# 4                   Mumbai  ₹ 11,000 - 17,000 /month  3 Months  Immediately
#
# ...

# %%
df.shape
# Out:
# (13616, 23)

# %%
df.columns.tolist()
# Out:
# ['title',
#  'company',
#  'location',
#  'stipend',
#  'duration',
#  'start_date',
#  'apply_by',
#  'openings',
#  'internship_type',
#  'work_mode',
#  'skills',
#  'description',
#  'perks',
#  'job_url',
#  'company_website',
#  'recruiter_email',
#  'domain_name',
#  'platform',
#  'scraped_date',
#  'salary',
#  'experience_required',
#  'posted_date',
#  'company_about']

# %%
df.isnull().sum()
# Out:
# title                      0
# company                    0
# location                2175
# stipend                10476
# duration               10599
# start_date             10599
# apply_by                8146
# openings                8708
# internship_type         7780
# work_mode               6934
# skills                  6046
# description             1885
# perks                   9917
# job_url                    0
# company_website        11543
# recruiter_email        13098
# domain_name            11632
# platform                3476
# scraped_date               0
# salary                  8899
# experience_required     9957
# posted_date             7158
# company_about          13610
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.describe(include="all")
# Out:
#                      title company                     location  \
# count                13616   13616                        11441
# unique                5363    6251                         1558
# top     typing work intern  Amazon  Bengaluru, Karnataka, India
# freq                   171     267                         1162
#
#                          stipend  duration   start_date     apply_by  \
# count                       3140      3017         3017         5470
# unique                       660        14           14          717
# top     ₹ 10,000 - 15,000 /month  6 Months  Immediately  24 Jun 2026
# freq                         154      1123         3002          362
#
#              openings internship_type work_mode  ...  \
# count            4908            5836      6682  ...
# unique             78               4         8  ...
# top     Not Disclosed       Full Time    Onsite  ...
# freq             1761            4930      2790  ...
#
# ...

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
