# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/job_data.csv")

# %%
df.head()
# Out:
#                                                title                  company  \
# 0  finance research analyst - internship wfh & pa...             edify equity
# 1                           digital marketing female        wear it like this
# 2                social media marketing - internship     madhuram hospitality
# 3                             pre sales - internship        dronacharya group
# 4   marketing support female candidates - internship  neeti brand accelerator
#
#             location_clean               stipend_clean duration_clean  \
# 0                    delhi    rs 1000 - 1100 per month        1 month
# 1  secunderabad, hyderabad  rs 10000 - 15000 per month        3 month
# 2                bangalore   rs 5000 - 10000 per month        3 month
# 3                 bhilwara   rs 9500 - 16000 per month        3 month
# 4                   mumbai  rs 11000 - 17000 per month        3 month
#
# ...

# %%
df.shape
# Out:
# (4661, 24)

# %%
df.columns.tolist()
# Out:
# ['title',
#  'company',
#  'location_clean',
#  'stipend_clean',
#  'duration_clean',
#  'start_date',
#  'apply_by',
#  'openings_clean',
#  'employment_type',
#  'work_mode',
#  'skills',
#  'description',
#  'perks',
#  'job_url',
#  'company_website',
#  'recruiter_email',
#  'domain_name',
#  'platform',
#  'scraped_date',
#  'salary_clean',
#  'experience_required_clean',
#  'posted_days_ago',
#  'company_about',
#  'is_internship']

# %%
df.isnull().sum()
# Out:
# title                           0
# company                         0
# location_clean                  0
# stipend_clean                1450
# duration_clean               1454
# start_date                   1454
# apply_by                     1454
# openings_clean               1317
# employment_type               399
# work_mode                    1454
# skills                        403
# description                   245
# perks                        1598
# job_url                         0
# company_website              2700
# recruiter_email              4436
# domain_name                  2758
# platform                        0
# scraped_date                    0
# salary_clean                 3211
# experience_required_clean    3610
# posted_days_ago              3611
# company_about                4473
# is_internship                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include="all")
# Out:
#                                           title    company location_clean  \
# count                                      4661       4661           4661
# unique                                     2314       3368            683
# top     business development sales - internship  cloudaxis         mumbai
# freq                                        164         28            472
# mean                                        NaN        NaN            NaN
# std                                         NaN        NaN            NaN
# min                                         NaN        NaN            NaN
# 25%                                         NaN        NaN            NaN
# 50%                                         NaN        NaN            NaN
# 75%                                         NaN        NaN            NaN
# max                                         NaN        NaN            NaN
#
#                      stipend_clean duration_clean   start_date  \
# ...

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
